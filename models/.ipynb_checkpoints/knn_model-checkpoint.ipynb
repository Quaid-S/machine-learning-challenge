# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

# %%
df = pd.read_csv("../data/exoplanet_data.csv")

df = df.dropna(axis='columns', how='all')

df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
X = df.drop(['koi_disposition', 'koi_srad_err1', 'koi_steff', 'koi_srad', 'koi_slogg_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_srad_err2', 'koi_tce_plnt_num'], axis=1)
y = df["koi_disposition"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_scaler = StandardScaler().fit(X_train.values.reshape(-1, 1))

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
train_scores = []
test_scores = []

for k in range(1, 80, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f'k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}')
# Out:
# k: 1, Train/Test Score: 1.000/0.600
# k: 3, Train/Test Score: 0.790/0.634
# k: 5, Train/Test Score: 0.750/0.645
# k: 7, Train/Test Score: 0.730/0.651
# k: 9, Train/Test Score: 0.721/0.659
# k: 11, Train/Test Score: 0.717/0.652
# k: 13, Train/Test Score: 0.710/0.658
# k: 15, Train/Test Score: 0.702/0.661
# k: 17, Train/Test Score: 0.700/0.658
# k: 19, Train/Test Score: 0.695/0.658
# k: 21, Train/Test Score: 0.695/0.660
# k: 23, Train/Test Score: 0.694/0.658
# k: 25, Train/Test Score: 0.689/0.657
# k: 27, Train/Test Score: 0.687/0.656
# k: 29, Train/Test Score: 0.686/0.653
# k: 31, Train/Test Score: 0.683/0.656
# k: 33, Train/Test Score: 0.680/0.656
# k: 35, Train/Test Score: 0.677/0.657
# k: 37, Train/Test Score: 0.675/0.652
# k: 39, Train/Test Score: 0.673/0.657
# k: 41, Train/Test Score: 0.672/0.657
# k: 43, Train/Test Score: 0.670/0.660
# k: 45, Train/Test Score: 0.669/0.658
# k: 47, Train/Test Score: 0.668/0.658
# k: 49, Train/Test Score: 0.666/0.657
# k: 51, Train/Test Score: 0.666/0.661
# k: 53, Train/Test Score: 0.665/0.659
# k: 55, Train/Test Score: 0.663/0.661
# k: 57, Train/Test Score: 0.665/0.656
# k: 59, Train/Test Score: 0.663/0.657
# k: 61, Train/Test Score: 0.663/0.654
# k: 63, Train/Test Score: 0.662/0.660
# k: 65, Train/Test Score: 0.659/0.656
# k: 67, Train/Test Score: 0.659/0.652
# k: 69, Train/Test Score: 0.658/0.651
# k: 71, Train/Test Score: 0.656/0.652
# k: 73, Train/Test Score: 0.655/0.649
# k: 75, Train/Test Score: 0.654/0.652
# k: 77, Train/Test Score: 0.656/0.650
# k: 79, Train/Test Score: 0.654/0.653

# %%
plt.plot(range(1, 80, 2), train_scores, marker='o')
plt.plot(range(1, 80, 2), test_scores, marker="x")
plt.xlabel('K Neighbors')
plt.ylabel('Testing Acc')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train_scaled, y_train)
print('k=15 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=15 Test Acc: 0.661
